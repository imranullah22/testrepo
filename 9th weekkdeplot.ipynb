# %%
from sklearn import datasets
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dd = pd.read_csv("imr.csv")

# %%
dd
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
dd=pd.DataFrame(dd)
dd
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#dd=dd.set_index("Id")
#print(dd)

# %%
dd
# Out:
#      Sepal_Length  Sepal_Width  Patal_Length  Petal_Width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
dd = datasets.load_iris()
dd_df = pd.DataFrame(dd.data, columns=['Sepal_Length','Sepal_Width', 'Patal_Length', 'Petal_Width'])    
dd_df['Species'] = dd.target 
dd_df['Species'].replace([0], 'Iris_Setosa', inplace=True)
dd_df['Species'].replace([1], 'Iris_Vercicolor', inplace=True)
dd_df['Species'].replace([2], 'Iris_Virginica', inplace=True)
dd_df
# Out:
#      Sepal_Length  Sepal_Width  Patal_Length  Petal_Width         Species
# 0             5.1          3.5           1.4          0.2     Iris_Setosa
# 1             4.9          3.0           1.4          0.2     Iris_Setosa
# 2             4.7          3.2           1.3          0.2     Iris_Setosa
# 3             4.6          3.1           1.5          0.2     Iris_Setosa
# 4             5.0          3.6           1.4          0.2     Iris_Setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris_Virginica
# 146           6.3          2.5           5.0          1.9  Iris_Virginica
# 147           6.5          3.0           5.2          2.0  Iris_Virginica
# 148           6.2          3.4           5.4          2.3  Iris_Virginica
# 149           5.9          3.0           5.1          1.8  Iris_Virginica
#
# [150 rows x 5 columns]

# %%
# Plotting the KDE Plot
sns.kdeplot(dd_df.loc[(dd_df['Species']=='Iris_Virginica'),
            'Sepal_Length'], color='b', shade=True, Label='Iris_Virginica')
  
# Setting the X and Y Label
plt.xlabel('Sepal Length')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')
