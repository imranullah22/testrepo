# %% [markdown]
# # 6th week

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Lemonade.csv")
df.head(10)
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0  01/01/2017     Sunday         27.0      2.00      15    0.3     10
# 1  02/01/2017     Monday         28.9      1.33      15    0.3     13
# 2  03/01/2017    Tuesday         34.5      1.33      27    0.3     15
# 3  04/01/2017  Wednesday         44.1      1.05      28    0.3     17
# 4  05/01/2017   Thursday         42.4      1.00      33    0.3     18
# 5  06/01/2017     Friday         25.3      1.54      23    0.3     11
# 6  07/01/2017   Saturday         32.9      1.54      19    0.3     13
# 7  08/01/2017     Sunday         37.5      1.18      28    0.3     15
# 8  09/01/2017     Monday         38.1      1.18      20    0.3     17
# 9  10/01/2017    Tuesday         43.4      1.05      33    0.3     18

# %%
df['Date']=pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)
df
# Out:
#                   Day  Temperature  Rainfall  Flyers  Price  Sales
# Date
# 2017-01-01     Sunday         27.0      2.00      15    0.3     10
# 2017-02-01     Monday         28.9      1.33      15    0.3     13
# 2017-03-01    Tuesday         34.5      1.33      27    0.3     15
# 2017-04-01  Wednesday         44.1      1.05      28    0.3     17
# 2017-05-01   Thursday         42.4      1.00      33    0.3     18
# ...               ...          ...       ...     ...    ...    ...
# 2017-12-27  Wednesday         42.7      1.00      33    0.3     19
# 2017-12-28   Thursday         37.8      1.25      32    0.3     16
# 2017-12-29     Friday         39.5      1.25      17    0.3     15
# 2017-12-30   Saturday         30.9      1.43      22    0.3     13
# 2017-12-31     Sunday         15.1      2.50       9    0.3      7
#
# [365 rows x 6 columns]

# %%
temperature=df['Temperature'].values
temperature
# Out:
# array([ 27. ,  28.9,  34.5,  44.1,  42.4,  25.3,  32.9,  37.5,  38.1,
#         43.4,  32.6,  38.2,  37.5,  44.1,  43.4,  30.6,  32.2,  42.8,
#         43.1,  31.6,  36.2,  40.8,  38.1,  28.6,  32.2,  35.8,  42.1,
#         34.9,  35.2,  41.1,  40.4,  42.4,  52. ,  50.3,  56.6,  45.4,
#         45. ,  52.3,  52.6,  42.7,  50. ,  51.3,  55.6,  46.4,  47.7,
#         52. ,  47.3,  40.4,  43.7,  50. ,  50.3,  42.4,  47.7,  45. ,
#         47.3,  42.4,  48.7,  45. ,  49.6,  57.9,  57.2,  60.2,  59.5,
#         55.9,  61.2,  60.2,  58.5,  52.9,  59.2,  58.2,  61.5,  55.9,
#         58.9,  56.2,  60.2,  56.5,  53.9,  56.9,  58.2,  57.2,  56.5,
#         55.9,  56.9,  58.2,  59.5,  60.5,  55.9,  57.2,  55.2,  58.5,
#         57.5,  65.8,  60.8,  62.1,  64.4,  57.5,  59.8,  63.8,  63.1,
#         58.5,  60.8,  66.1,  61.1,  61.5,  65.8,  65.1,  64.1,  62.5,
#         59.8,  68.1,  67.1,  57.5,  60.8,  65.1,  65.1,  62.5,  63.5,
# ...

# %%
temperature[0]
# Out:
# 27.0

# %%
day=df['Day'].values
day
# Out:
# array(['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#        'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday',
#        'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday',
#        'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday',
#        'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday',
#        'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday',
#        'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday',
#        'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#        'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday',
#        'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday',
#        'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday',
#        'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday',
#        'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday',
# ...

# %%
sales=df['Sales'].values
sales
# Out:
# array([10, 13, 15, 17, 18, 11, 13, 15, 17, 18, 12, 14, 15, 17, 18, 12, 14,
#        16, 17, 12, 14, 16, 17, 12, 14, 16, 17, 13, 14, 17, 18, 18, 20, 21,
#        22, 18, 20, 21, 22, 19, 20, 21, 22, 18, 19, 20, 21, 18, 19, 20, 21,
#        18, 19, 20, 21, 18, 19, 20, 22, 23, 24, 24, 25, 23, 24, 24, 25, 23,
#        24, 24, 25, 23, 23, 24, 24, 25, 23, 23, 24, 24, 25, 23, 23, 24, 25,
#        25, 23, 24, 24, 25, 25, 26, 26, 27, 28, 25, 26, 26, 27, 25, 26, 27,
#        27, 25, 26, 27, 27, 25, 26, 27, 27, 25, 26, 27, 27, 25, 25, 26, 27,
#        27, 29, 29, 30, 31, 28, 29, 29, 30, 31, 28, 29, 29, 30, 31, 28, 29,
#        29, 30, 31, 28, 29, 30, 31, 28, 29, 30, 31, 29, 29, 30, 31, 31, 33,
#        35, 38, 32, 34, 36, 39, 32, 35, 36, 40, 32, 35, 36, 41, 31, 32, 35,
#        37, 41, 31, 33, 35, 37, 42, 31, 33, 35, 38, 43, 38, 35, 34, 32, 39,
#        35, 34, 33, 40, 35, 34, 33, 40, 35, 34, 33, 41, 36, 35, 33, 42, 37,
# ...

# %%
day[0]
# Out:
# 'Sunday'

# %%
sales[0]
# Out:
# 10

# %%
rainfall=df['Rainfall'].values
rainfall
# Out:
# array([2.  , 1.33, 1.33, 1.05, 1.  , 1.54, 1.54, 1.18, 1.18, 1.05, 1.54,
#        1.33, 1.33, 1.05, 1.11, 1.67, 1.43, 1.18, 1.18, 1.43, 1.25, 1.11,
#        1.05, 1.54, 1.25, 1.25, 1.05, 1.33, 1.33, 1.05, 1.05, 1.  , 1.  ,
#        0.87, 0.83, 1.11, 0.95, 0.87, 0.87, 1.  , 0.91, 0.91, 0.83, 1.11,
#        0.95, 0.91, 0.87, 1.  , 0.95, 0.95, 0.95, 1.  , 0.95, 1.  , 0.87,
#        1.  , 1.05, 1.  , 0.91, 0.87, 0.8 , 0.77, 0.77, 0.87, 0.77, 0.77,
#        0.77, 0.8 , 0.83, 0.83, 0.74, 0.87, 0.87, 0.83, 0.83, 0.77, 0.83,
#        0.83, 0.77, 0.83, 0.74, 0.87, 0.83, 0.8 , 0.77, 0.74, 0.83, 0.83,
#        0.8 , 0.77, 0.8 , 0.74, 0.74, 0.71, 0.71, 0.8 , 0.74, 0.74, 0.69,
#        0.74, 0.74, 0.74, 0.69, 0.77, 0.74, 0.69, 0.71, 0.74, 0.77, 0.69,
#        0.74, 0.77, 0.77, 0.69, 0.71, 0.8 , 0.77, 0.74, 0.71, 0.74, 0.65,
#        0.69, 0.63, 0.63, 0.71, 0.67, 0.65, 0.67, 0.63, 0.69, 0.67, 0.67,
#        0.65, 0.63, 0.69, 0.67, 0.67, 0.67, 0.61, 0.67, 0.69, 0.67, 0.63,
# ...

# %%
rainfall[0]
# Out:
# 2.0

# %%
flyers=df['Flyers'].values
flyers
# Out:
# array([15, 15, 27, 28, 33, 23, 19, 28, 20, 33, 23, 16, 19, 23, 33, 24, 26,
#        33, 30, 20, 16, 19, 21, 20, 24, 18, 22, 15, 27, 20, 37, 35, 22, 25,
#        46, 32, 28, 39, 31, 39, 40, 35, 41, 34, 35, 33, 31, 29, 25, 28, 25,
#        28, 36, 23, 36, 21, 32, 34, 45, 46, 31, 28, 29, 32, 28, 32, 43, 29,
#        31, 30, 47, 48, 35, 30, 39, 50, 32, 38, 33, 36, 38, 35, 41, 50, 39,
#        30, 48, 39, 47, 48, 33, 47, 51, 31, 33, 31, 44, 37, 52, 48, 34, 30,
#        46, 49, 41, 43, 56, 31, 53, 42, 48, 47, 50, 48, 37, 48, 50, 32, 32,
#        35, 56, 40, 55, 64, 31, 51, 49, 56, 56, 40, 57, 40, 34, 58, 32, 55,
#        43, 53, 58, 59, 47, 34, 45, 34, 53, 63, 56, 45, 32, 43, 56, 42, 48,
#        59, 43, 36, 44, 58, 46, 44, 54, 42, 67, 65, 48, 50, 77, 47, 60, 66,
#        70, 76, 36, 39, 50, 58, 60, 62, 65, 64, 47, 59, 68, 68, 49, 55, 46,
#        41, 44, 44, 66, 40, 39, 49, 80, 56, 50, 64, 76, 44, 44, 59, 49, 72,
# ...

# %%
flyers[0]
# Out:
# 15

# %%
price=df['Price'].values
price

# %%
price[0]

# %%
Sales_mean=np.mean(sales)
Sales_mean

# %%
Rainfall_mean=np.mean(rainfall)
Rainfall_mean

# %%
Temperature_mean=np.mean(temperature)
Temperature_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-68b26d0dfd8d> in <module>
# ----> 1 Temperature_mean=np.mean(temperature)
#       2 Temperature_mean
#
# NameError: name 'np' is not defined

# %%
Price_mean=np.mean(price)
Price_mean

# %%
flyers_mean=np.mean(flyers)
flyers_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9787680ce3ec> in <module>
# ----> 1 flyers_mean=np.mean(flyers)
#       2 flyers_mean
#
# NameError: name 'np' is not defined

# %%
Sales_mean=np.mean(sales)
Sales_median=np.median(sales)
Sales_standarddeviation=np.std(sales)
Sales_varriance=np.var(sales)
print("mean of sale= ",Sales_mean)
print("median of sale=",Sales_median)
print("standarddeviation of sale =",Sales_standarddeviation)
print("varriance of sale =",Sales_varriance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-996f8e1ed3a9> in <module>
# ----> 1 Sales_mean=np.mean(sales)
#       2 Sales_median=np.median(sales)
#       3 Sales_standarddeviation=np.std(sales)
#       4 Sales_varriance=np.var(sales)
#       5 print("mean of sale= ",Sales_mean)
#
# NameError: name 'np' is not defined

# %%
Sales_mean=np.mean(temperature)
Sales_median=np.median(temperature)
Sales_standarddeviation=np.std(temperature)
Sales_varriance=np.var(temperature)
print("mean of temperature= ",Sales_mean)
print("median of temperature=",Sales_median)
print("standarddeviation of temperature =",Sales_standarddeviation)
print("varriance of temperature =",Sales_varriance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7f5f944d1777> in <module>
# ----> 1 Sales_mean=np.mean(temperature)
#       2 Sales_median=np.median(temperature)
#       3 Sales_standarddeviation=np.std(temperature)
#       4 Sales_varriance=np.var(temperature)
#       5 print("mean of temperature= ",Sales_mean)
#
# NameError: name 'np' is not defined

# %%
Sales_mean=np.mean(price)
Sales_median=np.median(price)
Sales_standarddeviation=np.std(price)
Sales_varriance=np.var(price)
print("mean of price= ",Sales_mean)
print("median of price=",Sales_median)
print("standarddeviation of price =",Sales_standarddeviation)
print("varriance of price =",Sales_varriance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-02f03e0a9dcd> in <module>
# ----> 1 Sales_mean=np.mean(price)
#       2 Sales_median=np.median(price)
#       3 Sales_standarddeviation=np.std(price)
#       4 Sales_varriance=np.var(price)
#       5 print("mean of price= ",Sales_mean)
#
# NameError: name 'np' is not defined

# %%
Sales_mean=np.mean(flyers)
Sales_median=np.median(flyers)
Sales_standarddeviation=np.std(flyers)
Sales_varriance=np.var(flyers)
print("mean of flyers= ",Sales_mean)
print("median of flyers=",Sales_median)
print("standarddeviation of flyers =",Sales_standarddeviation)
print("varriance of flyers =",Sales_varriance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-eb2a050a2a46> in <module>
# ----> 1 Sales_mean=np.mean(flyers)
#       2 Sales_median=np.median(flyers)
#       3 Sales_standarddeviation=np.std(flyers)
#       4 Sales_varriance=np.var(flyers)
#       5 print("mean of flyers= ",Sales_mean)
#
# NameError: name 'np' is not defined

# %%
Sales_mean=np.mean(rainfall)
Sales_median=np.median(rainfall)
Sales_standarddeviation=np.std(rainfall)
Sales_varriance=np.var(rainfall)
print("mean of rainfall= ",Sales_mean)
print("median of rainfall=",Sales_median)
print("standarddeviation of rainfall =",Sales_standarddeviation)
print("varriance of rainfall =",Sales_varriance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cd13d6d4f337> in <module>
# ----> 1 Sales_mean=np.mean(rainfall)
#       2 Sales_median=np.median(rainfall)
#       3 Sales_standarddeviation=np.std(rainfall)
#       4 Sales_varriance=np.var(rainfall)
#       5 print("mean of rainfall= ",Sales_mean)
#
# NameError: name 'np' is not defined

# %%
revenue=sales*price
revenue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d34546afa378> in <module>
# ----> 1 revenue=sales*price
#       2 revenue
#
# NameError: name 'sales' is not defined

# %%
revenue[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a022fc37da9f> in <module>
# ----> 1 revenue[0]
#
# NameError: name 'revenue' is not defined

# %%
plt.plot(sales,revenue)
plt.xlabel("sales")
plt.ylabel("revenue")
plt.title("sales vs revenue Graph")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7bbcb94c4441> in <module>
# ----> 1 plt.plot(sales,revenue)
#       2 plt.xlabel("sales")
#       3 plt.ylabel("revenue")
#       4 plt.title("sales vs revenue Graph")
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(15,10))
plt.hist(temperature)
plt.title("histograme of temperature")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a3e6c4f41c85> in <module>
# ----> 1 plt.figure(figsize=(15,10))
#       2 plt.hist(temperature)
#       3 plt.title("histograme of temperature")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(15,10))
plt.hist(price)
plt.title("histograme of price")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-aea74b7dee7f> in <module>
# ----> 1 plt.figure(figsize=(15,10))
#       2 plt.hist(price)
#       3 plt.title("histograme of price")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(15,10))
plt.hist(sales)
plt.title("histograme of sales")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-06022fa75a6c> in <module>
# ----> 1 plt.figure(figsize=(15,10))
#       2 plt.hist(sales)
#       3 plt.title("histograme of sales")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(15,10))
plt.hist(revenue)
plt.title("histograme of revenue")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-be15fb70cb90> in <module>
# ----> 1 plt.figure(figsize=(15,10))
#       2 plt.hist(revenue)
#       3 plt.title("histograme of revenue")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.subplot(3,2,1)
df['Price'].plot(figsize=(10,5))
plt.title("price")
plt.subplot(3,2,2)
df['Sales'].plot(figsize=(10,5))
plt.title('sales')
plt.subplot(3,2,3)
df['Temperature'].plot(figsize=(10,5))
plt.title('temperature')
plt.subplot(3,2,4)
df['Rainfall'].plot(figsize=(10,5))
plt.title("rainfall")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3d6dc94cfad2> in <module>
# ----> 1 plt.subplot(3,2,1)
#       2 df['Price'].plot(figsize=(10,5))
#       3 plt.title("price")
#       4 plt.subplot(3,2,2)
#       5 df['Sales'].plot(figsize=(10,5))
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(15,10))
plt.pie(temperature)
plt.title("pie chart of sales")
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(day,temperature)
plt.title("plot chart of sales and temperature")
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.hist(day)
plt.title("hist chart of sales")
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(day,sales)
plt.title("bar chart of sales")
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.scatter(sales,temperature)
plt.title("pie chart of sales")
plt.show()

# %%
df.describe()
df
# Out:
#                   Day  Temperature  Rainfall  Flyers  Price  Sales
# Date
# 2017-01-01     Sunday         27.0      2.00      15    0.3     10
# 2017-02-01     Monday         28.9      1.33      15    0.3     13
# 2017-03-01    Tuesday         34.5      1.33      27    0.3     15
# 2017-04-01  Wednesday         44.1      1.05      28    0.3     17
# 2017-05-01   Thursday         42.4      1.00      33    0.3     18
# ...               ...          ...       ...     ...    ...    ...
# 2017-12-27  Wednesday         42.7      1.00      33    0.3     19
# 2017-12-28   Thursday         37.8      1.25      32    0.3     16
# 2017-12-29     Friday         39.5      1.25      17    0.3     15
# 2017-12-30   Saturday         30.9      1.43      22    0.3     13
# 2017-12-31     Sunday         15.1      2.50       9    0.3      7
#
# [365 rows x 6 columns]

# %%
s=pd.Series([1,2,3,4])
s.describe()
# Out:
# count    4.000000
# mean     2.500000
# std      1.290994
# min      1.000000
# 25%      1.750000
# 50%      2.500000
# 75%      3.250000
# max      4.000000
# dtype: float64

# %%
s=pd.Series(['a','b','c'])
s.describe()
# Out:
# count     3
# unique    3
# top       c
# freq      1
# dtype: object
